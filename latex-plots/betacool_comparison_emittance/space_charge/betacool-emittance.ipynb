# %%
import numpy as np
import matplotlib.pyplot as plt
from pybetacool import PyBetaCool
from tqdm import tqdm

neutralisation_list = [0,0.5,1] # fraction

for i,neutralisation_space_charge_xs in enumerate(neutralisation_list):
    neutralisation_space_charge_betacool=(1-neutralisation_space_charge_xs)*100 #xsuite and betacool use different definitions of neutralisation
    BLDfilename = '/home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld'
    betacoolExec = '/home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool'
    obj = PyBetaCool(BLDfilename=BLDfilename, betacoolExec=betacoolExec)
    # Edit one parameter (row=50, 4th value is "magnetic field")
    obj.BLDContent[55][3] = neutralisation_space_charge_betacool 
    # Overwrites LEIR.bld with new setting 
    obj.BLDContent.save(BLDfilename)
    # Execute Betacool
    obj.runBetacool('/m')
    tmp = obj.parseCurveFile('emittance.cur')

    time=tmp[:,0]
    emittance_x = tmp[:,1]*1e-6
    emittance_y = tmp[:,2]*1e-6
    dp_p=tmp[:,3]

    filpath=f'results/emittance_betacool_SC={neutralisation_space_charge_xs}.npz'
    #reset the bld file back to default 
    obj.BLDContent[55][3] = 100 
    # Overwrites LEIR.bld with new setting 
    obj.BLDContent.save(BLDfilename)
    
    np.savez(filpath, time=time, emittance_x=emittance_x, emittance_y=emittance_y, dp_p=dp_p)

    # Print progress indication
    progress = (i + 1) / len(neutralisation_list) * 100
    print(f"Progress: {progress:.1f}%")
# Out:
# BETACOOL----------release ver.7.2.beta (omp)----------2023/7/13
# /home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool /home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld /m
# Input parameter [12,11] was initialised with default value:1e+10
# Cannot open file : Bring3.bump
# Mean beam radius= 0.1370049566  is more than chamber 4
# Model Beam: Integration Step [sec] =0.0002780286604
# Tcal[m.s]=0 Tref[s]=0 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.01 Tref[s]=0.004726487227 Ecool[%]=0.04 Core[%]=0 Impact=0
# Tcal[m.s]=0.02 Tref[s]=0.01445749034 Ecool[%]=0.03 Core[%]=0 Impact=0
# Tcal[m.s]=0.03 Tref[s]=0.02279835015 Ecool[%]=0.13 Core[%]=0 Impact=0
# Tcal[m.s]=0.04 Tref[s]=0.03141723863 Ecool[%]=0.16 Core[%]=0 Impact=0
# Tcal[m.s]=0.05 Tref[s]=0.04059218442 Ecool[%]=0.27 Core[%]=0 Impact=0
# Tcal[m.s]=0.06 Tref[s]=0.04948910155 Ecool[%]=0.47 Core[%]=0 Impact=0
# Tcal[m.s]=0.07 Tref[s]=0.05810799003 Ecool[%]=0.32 Core[%]=0 Impact=0
# Tcal[m.s]=0.08 Tref[s]=0.0667268785 Ecool[%]=0.43 Core[%]=0 Impact=0
# Tcal[m.s]=0.09 Tref[s]=0.07478970965 Ecool[%]=0.42 Core[%]=0 Impact=0
# Tcal[m.s]=0.1 Tref[s]=0.08313056947 Ecool[%]=0.41 Core[%]=0 Impact=0
# Tcal[m.s]=0.11 Tref[s]=0.0920274866 Ecool[%]=0.38 Core[%]=0 Impact=0
# Tcal[m.s]=0.12 Tref[s]=0.1012024324 Ecool[%]=0.45 Core[%]=0 Impact=0
# Tcal[m.s]=0.13 Tref[s]=0.1100993495 Ecool[%]=0.38 Core[%]=0 Impact=0
# Tcal[m.s]=0.14 Tref[s]=0.1189962667 Ecool[%]=0.51 Core[%]=0 Impact=0
# Tcal[m.s]=0.15 Tref[s]=0.1290052984 Ecool[%]=0.35 Core[%]=0 Impact=0
# Tcal[m.s]=0.16 Tref[s]=0.1381802442 Ecool[%]=0.44 Core[%]=0 Impact=0
# Tcal[m.s]=0.17 Tref[s]=0.1467991327 Ecool[%]=0.36 Core[%]=0 Impact=0
# Tcal[m.s]=0.18 Tref[s]=0.1556960498 Ecool[%]=0.48 Core[%]=0 Impact=0
# Tcal[m.s]=0.19 Tref[s]=0.1651490243 Ecool[%]=0.54 Core[%]=0 Impact=0
# Tcal[m.s]=0.2 Tref[s]=0.1734898841 Ecool[%]=0.42 Core[%]=0 Impact=0
# Tcal[m.s]=0.21 Tref[s]=0.1823868012 Ecool[%]=0.42 Core[%]=0 Impact=0
# Tcal[m.s]=0.22 Tref[s]=0.191561747 Ecool[%]=0.55 Core[%]=0 Impact=0
# Tcal[m.s]=0.23 Tref[s]=0.2010147215 Ecool[%]=0.61 Core[%]=0 Impact=0
# Tcal[m.s]=0.24 Tref[s]=0.2099116386 Ecool[%]=0.35 Core[%]=0 Impact=0
# Tcal[m.s]=0.25 Tref[s]=0.2199206704 Ecool[%]=0.62 Core[%]=0 Impact=0
# Tcal[m.s]=0.26 Tref[s]=0.2290956162 Ecool[%]=0.32 Core[%]=0 Impact=0
# Tcal[m.s]=0.27 Tref[s]=0.2379925333 Ecool[%]=0.38 Core[%]=0 Impact=0
# Tcal[m.s]=0.28 Tref[s]=0.2463333931 Ecool[%]=0.52 Core[%]=0 Impact=0
# Tcal[m.s]=0.29 Tref[s]=0.2555083389 Ecool[%]=0.41 Core[%]=0 Impact=0
# Tcal[m.s]=0.3 Tref[s]=0.2644052561 Ecool[%]=0.48 Core[%]=0 Impact=0
# Tcal[m.s]=0.31 Tref[s]=0.2727461159 Ecool[%]=0.57 Core[%]=0 Impact=0
# Tcal[m.s]=0.32 Tref[s]=0.281643033 Ecool[%]=0.41 Core[%]=0 Impact=0
# Tcal[m.s]=0.33 Tref[s]=0.2908179788 Ecool[%]=0.28 Core[%]=0 Impact=0
# Tcal[m.s]=0.34 Tref[s]=0.2999929246 Ecool[%]=0.48 Core[%]=0 Impact=0
# Tcal[m.s]=0.35 Tref[s]=0.3097239277 Ecool[%]=0.36 Core[%]=0 Impact=0
# Tcal[m.s]=0.36 Tref[s]=0.3188988735 Ecool[%]=0.61 Core[%]=0 Impact=0
# Tcal[m.s]=0.37 Tref[s]=0.328351848 Ecool[%]=0.47 Core[%]=0 Impact=0
# Tcal[m.s]=0.38 Tref[s]=0.3369707364 Ecool[%]=0.54 Core[%]=0 Impact=0
# Tcal[m.s]=0.39 Tref[s]=0.3458676536 Ecool[%]=0.38 Core[%]=0 Impact=0
# Tcal[m.s]=0.4 Tref[s]=0.3550425994 Ecool[%]=0.45 Core[%]=0 Impact=0
# Tcal[m.s]=0.41 Tref[s]=0.3639395165 Ecool[%]=0.38 Core[%]=0 Impact=0
# Tcal[m.s]=0.42 Tref[s]=0.3722803763 Ecool[%]=0.4 Core[%]=0 Impact=0
# Tcal[m.s]=0.43 Tref[s]=0.3806212361 Ecool[%]=0.48 Core[%]=0 Impact=0
# Tcal[m.s]=0.44 Tref[s]=0.3900742106 Ecool[%]=0.51 Core[%]=0 Impact=0
# Tcal[m.s]=0.45 Tref[s]=0.398693099 Ecool[%]=0.36 Core[%]=0 Impact=0
# Tcal[m.s]=0.46 Tref[s]=0.4078680448 Ecool[%]=0.35 Core[%]=0 Impact=0
# Tcal[m.s]=0.47 Tref[s]=0.416764962 Ecool[%]=0.47 Core[%]=0 Impact=0
# Tcal[m.s]=0.48 Tref[s]=0.4259399078 Ecool[%]=0.58 Core[%]=0 Impact=0
# Tcal[m.s]=0.49 Tref[s]=0.4345587962 Ecool[%]=0.5 Core[%]=0 Impact=0
# Tcal[m.s]=0.5 Tref[s]=0.4431776847 Ecool[%]=0.35 Core[%]=0 Impact=0
# Tcal[m.s]=0.51 Tref[s]=0.4520746018 Ecool[%]=0.46 Core[%]=0 Impact=0
# Tcal[m.s]=0.52 Tref[s]=0.4606934903 Ecool[%]=0.38 Core[%]=0 Impact=0
# Tcal[m.s]=0.53 Tref[s]=0.4693123788 Ecool[%]=0.48 Core[%]=0 Impact=0
# Tcal[m.s]=0.54 Tref[s]=0.4784873246 Ecool[%]=0.46 Core[%]=0 Impact=0
# Tcal[m.s]=0.55 Tref[s]=0.4873842417 Ecool[%]=0.45 Core[%]=0 Impact=0
# Tcal[m.s]=0.56 Tref[s]=0.4962811588 Ecool[%]=0.4 Core[%]=0 Impact=0
# Tcal[m.s]=0.57 Tref[s]=0.5046220187 Ecool[%]=0.42 Core[%]=0 Impact=0
# Tcal[m.s]=0.58 Tref[s]=0.5137969645 Ecool[%]=0.5 Core[%]=0 Impact=0
# Tcal[m.s]=0.59 Tref[s]=0.5229719102 Ecool[%]=0.49 Core[%]=0 Impact=0
# Tcal[m.s]=1 Tref[s]=0.5313127701 Ecool[%]=0.43 Core[%]=0 Impact=0
# Tcal[m.s]=1.01 Tref[s]=0.5402096872 Ecool[%]=0.34 Core[%]=0 Impact=0
# Tcal[m.s]=1.02 Tref[s]=0.5491066043 Ecool[%]=0.54 Core[%]=0 Impact=0
# Tcal[m.s]=1.03 Tref[s]=0.5580035215 Ecool[%]=0.4 Core[%]=0 Impact=0
# Tcal[m.s]=1.04 Tref[s]=0.5663443813 Ecool[%]=0.39 Core[%]=0 Impact=0
# Tcal[m.s]=1.05 Tref[s]=0.5749632697 Ecool[%]=0.37 Core[%]=0 Impact=0
# Tcal[m.s]=1.06 Tref[s]=0.5838601869 Ecool[%]=0.45 Core[%]=0 Impact=0
# Tcal[m.s]=1.07 Tref[s]=0.591923018 Ecool[%]=0.37 Core[%]=0 Impact=0
# Tcal[m.s]=1.08 Tref[s]=0.6008199352 Ecool[%]=0.36 Core[%]=0 Impact=0
# Tcal[m.s]=1.09 Tref[s]=0.6097168523 Ecool[%]=0.42 Core[%]=0 Impact=0
# Tcal[m.s]=1.1 Tref[s]=0.6188917981 Ecool[%]=0.5 Core[%]=0 Impact=0
# Tcal[m.s]=1.11 Tref[s]=0.6272326579 Ecool[%]=0.35 Core[%]=0 Impact=0
# Tcal[m.s]=1.12 Tref[s]=0.6358515464 Ecool[%]=0.58 Core[%]=0 Impact=0
# Tcal[m.s]=1.13 Tref[s]=0.6444704348 Ecool[%]=0.45 Core[%]=0 Impact=0
# Tcal[m.s]=1.14 Tref[s]=0.6522552373 Ecool[%]=0.37 Core[%]=0 Impact=0
# Tcal[m.s]=1.15 Tref[s]=0.6608741258 Ecool[%]=0.41 Core[%]=0 Impact=0
# Tcal[m.s]=1.16 Tref[s]=0.6703271003 Ecool[%]=0.37 Core[%]=0 Impact=0
# Tcal[m.s]=1.17 Tref[s]=0.6786679601 Ecool[%]=0.36 Core[%]=0 Impact=0
# Tcal[m.s]=1.18 Tref[s]=0.6878429059 Ecool[%]=0.54 Core[%]=0 Impact=0
# Tcal[m.s]=1.19 Tref[s]=0.6964617943 Ecool[%]=0.31 Core[%]=0 Impact=0
# Tcal[m.s]=1.2 Tref[s]=0.7050806828 Ecool[%]=0.29 Core[%]=0 Impact=0
# Tcal[m.s]=1.21 Tref[s]=0.713143514 Ecool[%]=0.31 Core[%]=0 Impact=0
# Tcal[m.s]=1.22 Tref[s]=0.7214843738 Ecool[%]=0.24 Core[%]=0 Impact=0
# Tcal[m.s]=1.23 Tref[s]=0.7303812909 Ecool[%]=0.27 Core[%]=0 Impact=0
# Tcal[m.s]=1.24 Tref[s]=0.7387221507 Ecool[%]=0.28 Core[%]=0 Impact=0
# Tcal[m.s]=1.25 Tref[s]=0.7476190679 Ecool[%]=0.25 Core[%]=0 Impact=0
# Tcal[m.s]=1.26 Tref[s]=0.7562379563 Ecool[%]=0.18 Core[%]=0 Impact=0
# Tcal[m.s]=1.27 Tref[s]=0.7645788162 Ecool[%]=0.19 Core[%]=0 Impact=0
# Tcal[m.s]=1.28 Tref[s]=0.7726416473 Ecool[%]=0.14 Core[%]=0 Impact=0
# Tcal[m.s]=1.29 Tref[s]=0.7809825071 Ecool[%]=0.08 Core[%]=0 Impact=0
# Tcal[m.s]=1.3 Tref[s]=0.7898794242 Ecool[%]=0.08 Core[%]=0 Impact=0
# Tcal[m.s]=1.31 Tref[s]=0.7993323987 Ecool[%]=0.09 Core[%]=0 Impact=0
# Tcal[m.s]=1.32 Tref[s]=0.8071172012 Ecool[%]=0.06 Core[%]=0 Impact=0
# Tcal[m.s]=1.33 Tref[s]=0.815458061 Ecool[%]=0.08 Core[%]=0 Impact=0
# Tcal[m.s]=1.34 Tref[s]=0.8243549781 Ecool[%]=0.06 Core[%]=0 Impact=0
# Tcal[m.s]=1.35 Tref[s]=0.8324178093 Ecool[%]=0.09 Core[%]=0 Impact=0
# Tcal[m.s]=1.36 Tref[s]=0.8410366978 Ecool[%]=0.05 Core[%]=0 Impact=0
# Tcal[m.s]=1.37 Tref[s]=0.8502116436 Ecool[%]=0.06 Core[%]=0 Impact=0
# Tcal[m.s]=1.38 Tref[s]=0.8593865894 Ecool[%]=0.06 Core[%]=0 Impact=0
# Tcal[m.s]=1.39 Tref[s]=0.8685615351 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=1.4 Tref[s]=0.8766243663 Ecool[%]=0.04 Core[%]=0 Impact=0
# Tcal[m.s]=1.41 Tref[s]=0.8849652261 Ecool[%]=0.07 Core[%]=0 Impact=0
# Tcal[m.s]=1.42 Tref[s]=0.8933060859 Ecool[%]=0.05 Core[%]=0 Impact=0
# Tcal[m.s]=1.43 Tref[s]=0.9010908884 Ecool[%]=0.05 Core[%]=0 Impact=0
# Tcal[m.s]=1.44 Tref[s]=0.9099878055 Ecool[%]=0.03 Core[%]=0 Impact=0
# Tcal[m.s]=1.45 Tref[s]=0.91944078 Ecool[%]=0.02 Core[%]=0 Impact=0
# Tcal[m.s]=1.46 Tref[s]=0.9269475538 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=1.47 Tref[s]=0.9352884136 Ecool[%]=0.03 Core[%]=0 Impact=0
# Tcal[m.s]=1.48 Tref[s]=0.9439073021 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=1.49 Tref[s]=0.9522481619 Ecool[%]=0.05 Core[%]=0 Impact=0
# Tcal[m.s]=1.5 Tref[s]=0.9605890217 Ecool[%]=0.03 Core[%]=0 Impact=0
# Tcal[m.s]=1.51 Tref[s]=0.9689298816 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=1.52 Tref[s]=0.9786608847 Ecool[%]=0.02 Core[%]=0 Impact=0
# Tcal[m.s]=1.53 Tref[s]=0.9867237158 Ecool[%]=0.04 Core[%]=0 Impact=0
# Tcal[m.s]=1.54 Tref[s]=0.9945085183 Ecool[%]=0 Core[%]=0 Impact=0
# STOP -2023/7/13-14:17:3
#
# TODO: simple version here...
# Progress: 33.3%
# BETACOOL----------release ver.7.2.beta (omp)----------2023/7/13
# /home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool /home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld /m
# Input parameter [12,11] was initialised with default value:1e+10
# Cannot open file : Bring3.bump
# Mean beam radius= 0.1370049566  is more than chamber 4
# Model Beam: Integration Step [sec] =0.0002780286604
# Tcal[m.s]=0 Tref[s]=0 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.01 Tref[s]=0.005560573208 Ecool[%]=0.61 Core[%]=0 Impact=0
# Tcal[m.s]=0.02 Tref[s]=0.01417946168 Ecool[%]=1.02 Core[%]=0 Impact=0
# Tcal[m.s]=0.03 Tref[s]=0.02224229283 Ecool[%]=1.27 Core[%]=0 Impact=0
# Tcal[m.s]=0.04 Tref[s]=0.03058315265 Ecool[%]=1.81 Core[%]=0 Impact=0
# Tcal[m.s]=0.05 Tref[s]=0.03920204112 Ecool[%]=2.51 Core[%]=0 Impact=0
# Tcal[m.s]=0.06 Tref[s]=0.04782092959 Ecool[%]=2.98 Core[%]=0 Impact=0
# Tcal[m.s]=0.07 Tref[s]=0.05588376074 Ecool[%]=3.33 Core[%]=0 Impact=0
# Tcal[m.s]=0.08 Tref[s]=0.06422462056 Ecool[%]=3.77 Core[%]=0 Impact=0
# Tcal[m.s]=0.09 Tref[s]=0.07200942305 Ecool[%]=4.45 Core[%]=0 Impact=0
# Tcal[m.s]=0.1 Tref[s]=0.08035028286 Ecool[%]=4.83 Core[%]=0 Impact=0
# Tcal[m.s]=0.11 Tref[s]=0.08896917133 Ecool[%]=5.22 Core[%]=0 Impact=0
# Tcal[m.s]=0.12 Tref[s]=0