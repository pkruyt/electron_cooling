# %%
import scipy.optimize
import math
import numpy as np
import matplotlib.pyplot as plt
from pybetacool import PyBetaCool



obj = PyBetaCool(BLDfilename='/home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld', betacoolExec='/home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool_Linux')
# Execute Betacool
obj.runBetacool('/m')
# Out:
# BETACOOL----------release ver.7.2.beta (omp)----------2023/6/22
# /home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool_Linux /home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld /m
# Input parameter [12,11] was initialised with default value:1e+10
# Cannot open file : Bring3.bump
# Mean beam radius= 0.1370049566  is more than chamber 4
# Model Beam: Integration Step [sec] =0.0002780286604
# Tcal[m.s]=0 Tref[s]=0 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.01 Tref[s]=0.00639465919 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.02 Tref[s]=0.0133453757 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.03 Tref[s]=0.02029609221 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.04 Tref[s]=0.0280808947 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.05 Tref[s]=0.03586569719 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.06 Tref[s]=0.04170429906 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.07 Tref[s]=0.04921107289 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.08 Tref[s]=0.05699587539 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.09 Tref[s]=0.06366856324 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.1 Tref[s]=0.07034125109 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.11 Tref[s]=0.07756999626 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.12 Tref[s]=0.08424268411 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.13 Tref[s]=0.09035931464 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.14 Tref[s]=0.09591988784 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.15 Tref[s]=0.1034266617 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.16 Tref[s]=0.1095432922 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.17 Tref[s]=0.1145478081 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.18 Tref[s]=0.1189962667 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=0.19 Tref[s]=0.1251128972 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=0.2 Tref[s]=0.1312295277 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.21 Tref[s]=0.1365120723 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.22 Tref[s]=0.1426287028 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.23 Tref[s]=0.1479112473 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.24 Tref[s]=0.1540278779 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.25 Tref[s]=0.1598664797 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.26 Tref[s]=0.1665391676 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.27 Tref[s]=0.1720997408 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.28 Tref[s]=0.1782163713 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=0.29 Tref[s]=0.1848890592 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.3 Tref[s]=0.1904496324 Ecool[%]=0.02 Core[%]=0 Impact=0
# Tcal[m.s]=0.31 Tref[s]=0.1965662629 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.32 Tref[s]=0.2024048648 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.33 Tref[s]=0.207965438 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.34 Tref[s]=0.2149161545 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.35 Tref[s]=0.2201986991 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.36 Tref[s]=0.2254812436 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.37 Tref[s]=0.2318759028 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.38 Tref[s]=0.237436476 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.39 Tref[s]=0.2435531065 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.4 Tref[s]=0.2491136797 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=0.41 Tref[s]=0.2543962243 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.42 Tref[s]=0.2582886255 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.43 Tref[s]=0.2646832847 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.44 Tref[s]=0.2705218866 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.45 Tref[s]=0.2763604885 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.46 Tref[s]=0.2830331763 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.47 Tref[s]=0.2885937495 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.48 Tref[s]=0.2935982654 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.49 Tref[s]=0.2991588386 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=0.5 Tref[s]=0.3055534978 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.51 Tref[s]=0.3116701283 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.52 Tref[s]=0.3183428162 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.53 Tref[s]=0.325015504 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.54 Tref[s]=0.3316881919 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.55 Tref[s]=0.3386389084 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.56 Tref[s]=0.3455896249 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.57 Tref[s]=0.3517062554 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=0.58 Tref[s]=0.3581009146 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.59 Tref[s]=0.3639395165 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1 Tref[s]=0.3706122043 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.01 Tref[s]=0.3767288349 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.02 Tref[s]=0.3836795514 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.03 Tref[s]=0.3900742106 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.04 Tref[s]=0.3964688698 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.05 Tref[s]=0.4036976149 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.06 Tref[s]=0.4100922741 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.07 Tref[s]=0.416764962 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.08 Tref[s]=0.4237156785 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.09 Tref[s]=0.4284421657 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.1 Tref[s]=0.4337247103 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.11 Tref[s]=0.4395633121 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.12 Tref[s]=0.4465140286 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=1.13 Tref[s]=0.4526306592 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.14 Tref[s]=0.4579132037 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.15 Tref[s]=0.4643078629 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.16 Tref[s]=0.4698684361 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.17 Tref[s]=0.474872952 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.18 Tref[s]=0.4798774679 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.19 Tref[s]=0.4862721271 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.2 Tref[s]=0.4923887576 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.21 Tref[s]=0.4990614455 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.22 Tref[s]=0.506012162 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=1.23 Tref[s]=0.5126848498 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.24 Tref[s]=0.5193575377 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.25 Tref[s]=0.5246400822 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=1.26 Tref[s]=0.5293665694 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.27 Tref[s]=0.5349271426 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.28 Tref[s]=0.5402096872 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.29 Tref[s]=0.5446581458 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.3 Tref[s]=0.550218719 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=1.31 Tref[s]=0.5552232349 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.32 Tref[s]=0.5607838081 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.33 Tref[s]=0.565788324 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.34 Tref[s]=0.5710708685 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.35 Tref[s]=0.5760753844 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.36 Tref[s]=0.5816359576 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.37 Tref[s]=0.5871965308 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.38 Tref[s]=0.592757104 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.39 Tref[s]=0.5977616199 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.4 Tref[s]=0.6036002218 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.41 Tref[s]=0.609994881 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.42 Tref[s]=0.6166675688 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.43 Tref[s]=0.6233402567 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.44 Tref[s]=0.6300129445 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.45 Tref[s]=0.6364076037 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.46 Tref[s]=0.6433583202 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.47 Tref[s]=0.6503090367 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=1.48 Tref[s]=0.6567036959 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.49 Tref[s]=0.6639324411 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.5 Tref[s]=0.6708831576 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.51 Tref[s]=0.6778338741 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.52 Tref[s]=0.6850626193 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.53 Tref[s]=0.6909012211 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.54 Tref[s]=0.6981299663 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.55 Tref[s]=0.7053587115 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.56 Tref[s]=0.711475342 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=1.57 Tref[s]=0.7181480299 Ecool[%]=0.02 Core[%]=0 Impact=0
# Tcal[m.s]=1.58 Tref[s]=0.7256548037 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.59 Tref[s]=0.7320494629 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2 Tref[s]=0.7384441221 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=2.01 Tref[s]=0.7453948386 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.02 Tref[s]=0.7520675264 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.03 Tref[s]=0.7587402143 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.04 Tref[s]=0.7654129021 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.05 Tref[s]=0.7718075613 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.06 Tref[s]=0.7784802492 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.07 Tref[s]=0.7857089943 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.08 Tref[s]=0.7921036535 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.09 Tref[s]=0.7984983127 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.1 Tref[s]=0.8060050866 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.11 Tref[s]=0.8118436884 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.12 Tref[s]=0.8185163763 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.13 Tref[s]=0.8249110355 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.14 Tref[s]=0.8315837233 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=2.15 Tref[s]=0.8382564112 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.16 Tref[s]=0.8454851563 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.17 Tref[s]=0.8524358728 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.18 Tref[s]=0.8593865894 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.19 Tref[s]=0.8663373059 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.2 Tref[s]=0.8727319651 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.21 Tref[s]=0.8794046529 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.22 Tref[s]=0.8866333981 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.23 Tref[s]=0.8930280573 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.24 Tref[s]=0.8991446878 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.25 Tref[s]=0.9058173756 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=2.26 Tref[s]=0.9116559775 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.27 Tref[s]=0.9180506367 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.28 Tref[s]=0.9250013532 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.29 Tref[s]=0.9313960124 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.3 Tref[s]=0.9377906716 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=2.31 Tref[s]=0.9450194168 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.32 Tref[s]=0.951414076 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.33 Tref[s]=0.9583647925 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.34 Tref[s]=0.9655935376 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.35 Tref[s]=0.9717101682 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=2.36 Tref[s]=0.9781048274 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.37 Tref[s]=0.9850555439 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.38 Tref[s]=0.9914502031 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.39 Tref[s]=0.9978448622 Ecool[%]=0 Core[%]=0 Impact=0
# STOP -2023/6/22-10:51:41
# False

# %%
tmp = obj.parseCurveFile('emittance.cur')

time=tmp[:,0]
emittance_x = tmp[:,1]*1e-6
emittance_y = tmp[:,2]
plt.figure()
plt.plot(time,emittance_x, label='emittance')


plt.title('betacool')
plt.ylabel('Emittance')
plt.xlabel('Time')
plt.legend()
plt.show()
# Out:
# TODO: simple version here...

# %%
filpath='results/emittance_betacool_T_l=0.1.npz'

np.savez(filpath, time=time, emittance_x=emittance_x, emittance_y=emittance_y)
