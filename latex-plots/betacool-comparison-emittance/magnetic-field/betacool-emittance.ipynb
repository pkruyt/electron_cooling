# %%
import scipy.optimize
import math
import numpy as np
import matplotlib.pyplot as plt
from pybetacool import PyBetaCool



obj = PyBetaCool(BLDfilename='/home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld', betacoolExec='/home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool_Linux')
# Execute Betacool
obj.runBetacool('/m')
# Out:
# BETACOOL----------release ver.7.2.beta (omp)----------2023/6/22
# /home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool_Linux /home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld /m
# Input parameter [12,11] was initialised with default value:1e+10
# Cannot open file : Bring3.bump
# Mean beam radius= 0.1370049566  is more than chamber 4
# Model Beam: Integration Step [sec] =0.0002780286604
# Tcal[m.s]=0 Tref[s]=0 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.01 Tref[s]=0.005004515888 Ecool[%]=0.11 Core[%]=0 Impact=0
# Tcal[m.s]=0.02 Tref[s]=0.01167720374 Ecool[%]=0.2 Core[%]=0 Impact=0
# Tcal[m.s]=0.03 Tref[s]=0.01807186293 Ecool[%]=0.13 Core[%]=0 Impact=0
# Tcal[m.s]=0.04 Tref[s]=0.02502257944 Ecool[%]=0.25 Core[%]=0 Impact=0
# Tcal[m.s]=0.05 Tref[s]=0.03141723863 Ecool[%]=0.34 Core[%]=0 Impact=0
# Tcal[m.s]=0.06 Tref[s]=0.03753386916 Ecool[%]=0.47 Core[%]=0 Impact=0
# Tcal[m.s]=0.07 Tref[s]=0.04420655701 Ecool[%]=0.4 Core[%]=0 Impact=0
# Tcal[m.s]=0.08 Tref[s]=0.05032318754 Ecool[%]=0.49 Core[%]=0 Impact=0
# Tcal[m.s]=0.09 Tref[s]=0.05643981806 Ecool[%]=0.62 Core[%]=0 Impact=0
# Tcal[m.s]=0.1 Tref[s]=0.06283447725 Ecool[%]=0.7 Core[%]=0 Impact=0
# Tcal[m.s]=0.11 Tref[s]=0.0695071651 Ecool[%]=0.84 Core[%]=0 Impact=0
# Tcal[m.s]=0.12 Tref[s]=0.07701393894 Ecool[%]=0.84 Core[%]=0 Impact=0
# Tcal[m.s]=0.13 Tref[s]=0.08340859813 Ecool[%]=0.96 Core[%]=0 Impact=0
# Tcal[m.s]=0.14 Tref[s]=0.08980325732 Ecool[%]=0.79 Core[%]=0 Impact=0
# Tcal[m.s]=0.15 Tref[s]=0.09675397383 Ecool[%]=0.99 Core[%]=0 Impact=0
# Tcal[m.s]=0.16 Tref[s]=0.1028706044 Ecool[%]=1 Core[%]=0 Impact=0
# Tcal[m.s]=0.17 Tref[s]=0.1092652635 Ecool[%]=0.96 Core[%]=0 Impact=0
# Tcal[m.s]=0.18 Tref[s]=0.1153818941 Ecool[%]=1.06 Core[%]=0 Impact=0
# Tcal[m.s]=0.19 Tref[s]=0.1206644386 Ecool[%]=1.03 Core[%]=0 Impact=0
# Tcal[m.s]=0.2 Tref[s]=0.1262250118 Ecool[%]=1.13 Core[%]=0 Impact=0
# Tcal[m.s]=0.21 Tref[s]=0.1328976997 Ecool[%]=1.24 Core[%]=0 Impact=0
# Tcal[m.s]=0.22 Tref[s]=0.1392923589 Ecool[%]=1.34 Core[%]=0 Impact=0
# Tcal[m.s]=0.23 Tref[s]=0.1462430754 Ecool[%]=1.06 Core[%]=0 Impact=0
# Tcal[m.s]=0.24 Tref[s]=0.1526377346 Ecool[%]=1.11 Core[%]=0 Impact=0
# Tcal[m.s]=0.25 Tref[s]=0.1593104224 Ecool[%]=1.14 Core[%]=0 Impact=0
# Tcal[m.s]=0.26 Tref[s]=0.1662611389 Ecool[%]=0.92 Core[%]=0 Impact=0
# Tcal[m.s]=0.27 Tref[s]=0.1718217121 Ecool[%]=1.2 Core[%]=0 Impact=0
# Tcal[m.s]=0.28 Tref[s]=0.1787724286 Ecool[%]=1.28 Core[%]=0 Impact=0
# Tcal[m.s]=0.29 Tref[s]=0.1860011738 Ecool[%]=1.43 Core[%]=0 Impact=0
# Tcal[m.s]=0.3 Tref[s]=0.192395833 Ecool[%]=1.21 Core[%]=0 Impact=0
# Tcal[m.s]=0.31 Tref[s]=0.1990685209 Ecool[%]=1.31 Core[%]=0 Impact=0
# Tcal[m.s]=0.32 Tref[s]=0.2065752947 Ecool[%]=1.14 Core[%]=0 Impact=0
# Tcal[m.s]=0.33 Tref[s]=0.2129699539 Ecool[%]=1.39 Core[%]=0 Impact=0
# Tcal[m.s]=0.34 Tref[s]=0.2193646131 Ecool[%]=1.42 Core[%]=0 Impact=0
# Tcal[m.s]=0.35 Tref[s]=0.2265933582 Ecool[%]=1.3 Core[%]=0 Impact=0
# Tcal[m.s]=0.36 Tref[s]=0.2327099888 Ecool[%]=1.25 Core[%]=0 Impact=0
# Tcal[m.s]=0.37 Tref[s]=0.2393826766 Ecool[%]=1.27 Core[%]=0 Impact=0
# Tcal[m.s]=0.38 Tref[s]=0.2460553645 Ecool[%]=1.33 Core[%]=0 Impact=0
# Tcal[m.s]=0.39 Tref[s]=0.2527280523 Ecool[%]=1.31 Core[%]=0 Impact=0
# Tcal[m.s]=0.4 Tref[s]=0.2596787688 Ecool[%]=1.34 Core[%]=0 Impact=0
# Tcal[m.s]=0.41 Tref[s]=0.266907514 Ecool[%]=1.39 Core[%]=0 Impact=0
# Tcal[m.s]=0.42 Tref[s]=0.2733021732 Ecool[%]=1.5 Core[%]=0 Impact=0
# Tcal[m.s]=0.43 Tref[s]=0.2791407751 Ecool[%]=1.47 Core[%]=0 Impact=0
# Tcal[m.s]=0.44 Tref[s]=0.2866475489 Ecool[%]=1.33 Core[%]=0 Impact=0
# Tcal[m.s]=0.45 Tref[s]=0.2930422081 Ecool[%]=1.35 Core[%]=0 Impact=0
# Tcal[m.s]=0.46 Tref[s]=0.2997148959 Ecool[%]=1.62 Core[%]=0 Impact=0
# Tcal[m.s]=0.47 Tref[s]=0.3066656124 Ecool[%]=1.59 Core[%]=0 Impact=0
# Tcal[m.s]=0.48 Tref[s]=0.3133383003 Ecool[%]=1.28 Core[%]=0 Impact=0
# Tcal[m.s]=0.49 Tref[s]=0.3202890168 Ecool[%]=1.44 Core[%]=0 Impact=0
# Tcal[m.s]=0.5 Tref[s]=0.3264056473 Ecool[%]=1.62 Core[%]=0 Impact=0
# Tcal[m.s]=0.51 Tref[s]=0.3333563638 Ecool[%]=1.54 Core[%]=0 Impact=0
# Tcal[m.s]=0.52 Tref[s]=0.3403070804 Ecool[%]=1.65 Core[%]=0 Impact=0
# Tcal[m.s]=0.53 Tref[s]=0.3469797682 Ecool[%]=1.53 Core[%]=0 Impact=0
# Tcal[m.s]=0.54 Tref[s]=0.3542085134 Ecool[%]=1.53 Core[%]=0 Impact=0
# Tcal[m.s]=0.55 Tref[s]=0.3606031726 Ecool[%]=1.55 Core[%]=0 Impact=0
# Tcal[m.s]=0.56 Tref[s]=0.3672758604 Ecool[%]=1.38 Core[%]=0 Impact=0
# Tcal[m.s]=0.57 Tref[s]=0.3739485483 Ecool[%]=1.63 Core[%]=0 Impact=0
# Tcal[m.s]=0.58 Tref[s]=0.3789530642 Ecool[%]=1.66 Core[%]=0 Impact=0
# Tcal[m.s]=0.59 Tref[s]=0.3853477233 Ecool[%]=1.49 Core[%]=0 Impact=0
# Tcal[m.s]=1 Tref[s]=0.3911863252 Ecool[%]=1.6 Core[%]=0 Impact=0
# Tcal[m.s]=1.01 Tref[s]=0.3978590131 Ecool[%]=1.66 Core[%]=0 Impact=0
# Tcal[m.s]=1.02 Tref[s]=0.4042536722 Ecool[%]=1.39 Core[%]=0 Impact=0
# Tcal[m.s]=1.03 Tref[s]=0.4106483314 Ecool[%]=1.6 Core[%]=0 Impact=0
# Tcal[m.s]=1.04 Tref[s]=0.4170429906 Ecool[%]=1.85 Core[%]=0 Impact=0
# Tcal[m.s]=1.05 Tref[s]=0
Core[%]=0 Impact=0
# Tcal[m.s]=2.1 Tref[s]=0.8518798155 Ecool[%]=1.35 Core[%]=0 Impact=0
# Tcal[m.s]=2.11 Tref[s]=0.8593865894 Ecool[%]=1.74 Core[%]=0 Impact=0
# Tcal[m.s]=2.12 Tref[s]=0.8660592772 Ecool[%]=1.37 Core[%]=0 Impact=0
# Tcal[m.s]=2.13 Tref[s]=0.8727319651 Ecool[%]=1.38 Core[%]=0 Impact=0
# Tcal[m.s]=2.14 Tref[s]=0.8791266242 Ecool[%]=1.27 Core[%]=0 Impact=0
# Tcal[m.s]=2.15 Tref[s]=0.8866333981 Ecool[%]=1.41 Core[%]=0 Impact=0
# Tcal[m.s]=2.16 Tref[s]=0.8935841146 Ecool[%]=1.43 Core[%]=0 Impact=0
# Tcal[m.s]=2.17 Tref[s]=0.9002568024 Ecool[%]=1.26 Core[%]=0 Impact=0
# Tcal[m.s]=2.18 Tref[s]=0.9066514616 Ecool[%]=1.12 Core[%]=0 Impact=0
# Tcal[m.s]=2.19 Tref[s]=0.9133241495 Ecool[%]=1.19 Core[%]=0 Impact=0
# Tcal[m.s]=2.2 Tref[s]=0.920274866 Ecool[%]=0.95 Core[%]=0 Impact=0
# Tcal[m.s]=2.21 Tref[s]=0.9266695252 Ecool[%]=0.96 Core[%]=0 Impact=0
# Tcal[m.s]=2.22 Tref[s]=0.9338982703 Ecool[%]=0.82 Core[%]=0 Impact=0
# Tcal[m.s]=2.23 Tref[s]=0.9402929295 Ecool[%]=0.86 Core[%]=0 Impact=0
# Tcal[m.s]=2.24 Tref[s]=0.9469656174 Ecool[%]=0.78 Core[%]=0 Impact=0
# Tcal[m.s]=2.25 Tref[s]=0.9541943626 Ecool[%]=0.62 Core[%]=0 Impact=0
# Tcal[m.s]=2.26 Tref[s]=0.9605890217 Ecool[%]=0.74 Core[%]=0 Impact=0
# Tcal[m.s]=2.27 Tref[s]=0.9664276236 Ecool[%]=0.74 Core[%]=0 Impact=0
# Tcal[m.s]=2.28 Tref[s]=0.9736563688 Ecool[%]=0.67 Core[%]=0 Impact=0
# Tcal[m.s]=2.29 Tref[s]=0.9803290566 Ecool[%]=0.49 Core[%]=0 Impact=0
# Tcal[m.s]=2.3 Tref[s]=0.9861676585 Ecool[%]=0.56 Core[%]=0 Impact=0
# Tcal[m.s]=2.31 Tref[s]=0.9933964037 Ecool[%]=0.52 Core[%]=0 Impact=0
# Tcal[m.s]=2.32 Tref[s]=1.000069092 Ecool[%]=0.54 Core[%]=0 Impact=0
# STOP -2023/6/22-11:35:40
# False

# %%
tmp = obj.parseCurveFile('emittance.cur')

time=tmp[:,0]
emittance_x = tmp[:,1]*1e-6
emittance_y = tmp[:,2]
plt.figure()
plt.plot(time,emittance_x, label='emittance')


plt.title('betacool')
plt.ylabel('Emittance')
plt.xlabel('Time')
plt.legend()
plt.show()
# Out:
# TODO: simple version here...

# %%
filpath='results/emittance_betacool_B=0.01.npz'

np.savez(filpath, time=time, emittance_x=emittance_x, emittance_y=emittance_y)
