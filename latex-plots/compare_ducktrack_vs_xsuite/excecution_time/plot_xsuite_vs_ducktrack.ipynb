# %%
# copyright ############################### #
# This file is part of the Xtrack Package.  #
# Copyright (c) CERN, 2021.                 #
# ######################################### #

import xtrack as xt
import xobjects as xo
import xpart as xp

import ducktrack as dtk
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm


filepath = f'results/execution_time_ducktrack.npz'
data_ducktrack=np.load(filepath)
num_particles=data_ducktrack['num_particles']
excecution_time_ducktrack=data_ducktrack['excecution_time']

data_xsuite=filepath = f'results/execution_time_xsuite.npz'
data_xsuite=np.load(filepath)
excecution_time_xsuite=data_xsuite['excecution_time']

plt.figure()
plt.plot(num_particles,excecution_time_ducktrack,label='ducktrack')
plt.plot(num_particles,excecution_time_xsuite,label='xsuite')
plt.ylabel('Excecution time [s]')
plt.xlabel('Number of particles')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 27
#      25 plt.figure()
#      26 plt.plot(num_particles,excecution_time_ducktrack,label='ducktrack')
# ---> 27 plt.plot(num_particles,excecution_time_xsuite,label='xsuite')
#      28 plt.ylabel('Excecution time [s]')
#      29 plt.xlabel('Number of particles')
#
# File ~/miniforge3/envs/xsuite/lib/python3.11/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
