# %%
import numpy as np
import matplotlib.pyplot as plt
from pybetacool import PyBetaCool
from tqdm import tqdm


current_list = [1,2,3] # A

for i,current in tqdm(enumerate(current_list)):
    BLDfilename = '../../LEIR.bld'
    betacoolExec = '../../../betacool/Betacool'
    obj = PyBetaCool(BLDfilename=BLDfilename, betacoolExec=betacoolExec)
    # Edit one parameter (row=50, 4th value is "magnetic field")
    obj.BLDContent[55][2] = current 
    # Overwrites LEIR.bld with new setting 
    obj.BLDContent.save(BLDfilename)
    # Execute Betacool
    obj.runBetacool('/m')
    tmp = obj.parseCurveFile('emittance.cur')

    time=tmp[:,0]
    emittance_x = tmp[:,1]*1e-6
    emittance_y = tmp[:,2]*1e-6
    dp_p=tmp[:,3]

    filpath=f'results/emittance_betacool_I={current}.npz'
     #reset the bld file back to default 
    obj.BLDContent[55][2] = 0.6
    # Overwrites LEIR.bld with new setting 
    obj.BLDContent.save(BLDfilename)
    
    np.savez(filpath, time=time, emittance_x=emittance_x, emittance_y=emittance_y, dp_p=dp_p)
# Out:
# 1it [02:23, 143.63s/it]
# BETACOOL----------release ver.7.2.beta (omp)----------2024/12/19
# ../../betacool/Betacool ../../LEIR.bld /m
# Input parameter [12,11] was initialised with default value:1e+10
# Cannot open file : Bring3.bump
# Mean beam radius= 0.1370049566  is more than chamber 4
# Model Beam: Integration Step [sec] =0.0002780286604
# Tcal[m.s]=0 Tref[s]=0 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.01 Tref[s]=0.003336343925 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.02 Tref[s]=0.01028706044 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.03 Tref[s]=0.01751580561 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.04 Tref[s]=0.02502257944 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.05 Tref[s]=0.03113920997 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.06 Tref[s]=0.03836795514 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.07 Tref[s]=0.04587472897 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.08 Tref[s]=0.05226938816 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.09 Tref[s]=0.05977616199 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.1 Tref[s]=0.06700490716 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.11 Tref[s]=0.07339956635 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.12 Tref[s]=0.08062831152 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.13 Tref[s]=0.08785705669 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.14 Tref[s]=0.09564185918 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.15 Tref[s]=0.1009244037 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.16 Tref[s]=0.1075970916 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.17 Tref[s]=0.1145478081 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.18 Tref[s]=0.1206644386 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.19 Tref[s]=0.1284492411 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.2 Tref[s]=0.1359560149 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.21 Tref[s]=0.1431847601 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.22 Tref[s]=0.1504135053 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.23 Tref[s]=0.1576422505 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.24 Tref[s]=0.1659831103 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.25 Tref[s]=0.1732118554 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.26 Tref[s]=0.1804406006 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.27 Tref[s]=0.1882254031 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.28 Tref[s]=0.1954541483 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.29 Tref[s]=0.2021268361 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.3 Tref[s]=0.2099116386 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.31 Tref[s]=0.2179744698 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.32 Tref[s]=0.2252032149 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.33 Tref[s]=0.2327099888 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.34 Tref[s]=0.2360463327 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.35 Tref[s]=0.2424409919 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.36 Tref[s]=0.2496697371 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.37 Tref[s]=0.2566204536 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.38 Tref[s]=0.2635711701 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.39 Tref[s]=0.2710779439 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.4 Tref[s]=0.2780286604 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.41 Tref[s]=0.2844233196 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.42 Tref[s]=0.2913740361 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.43 Tref[s]=0.2991588386 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.44 Tref[s]=0.3077777271 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.45 Tref[s]=0.3155625296 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.46 Tref[s]=0.3214011314 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.47 Tref[s]=0.3277957906 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.48 Tref[s]=0.3358586218 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.49 Tref[s]=0.3439214529 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.5 Tref[s]=0.3511501981 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.51 Tref[s]=0.3589350006 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.52 Tref[s]=0.3667198031 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.53 Tref[s]=0.3736705196 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.54 Tref[s]=0.3814553221 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.55 Tref[s]=0.3889620959 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.56 Tref[s]=0.3970249271 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.57 Tref[s]=0.4048097296 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.58 Tref[s]=0.4114824174 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.59 Tref[s]=0.4178770766 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1 Tref[s]=0.4259399078 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.01 Tref[s]=0.4331686529 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.02 Tref[s]=0.4406754268 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.03 Tref[s]=0.4479041719 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.04 Tref[s]=0.4551329171 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.05 Tref[s]=0.460971519 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.06 Tref[s]=0.4682002641 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.07 Tref[s]=0.4762630953 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.08 Tref[s]=0.4834918405 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.09 Tref[s]=0.4898864997 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.1 Tref[s]=0.4971152448 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.11 Tref[s]=0.5040659613 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.12 Tref[s]=0.5110166778 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.13 Tref[s]=0.5188014803 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.14 Tref[s]=0.5271423402 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.15 Tref[s]=0.5340930567 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.16 Tref[s]=0.5407657445 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.17 Tref[s]=0.5466043464 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.18 Tref[s]=0.5546671775 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.19 Tref[s]=0.5621739514 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.2 Tref[s]=0.5696807252 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.21 Tref[s]=0.577187499 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.22 Tref[s]=0.5835821582 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.23 Tref[s]=0.5902548461 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.24 Tref[s]=0.5977616199 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.25 Tref[s]=0.6055464224 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.26 Tref[s]=0.6127751676 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.27 Tref[s]=0.6188917981 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.28 Tref[s]=0.6255644859 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.29 Tref[s]=0.6314030878 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.3 Tref[s]=0.6380757757 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.31 Tref[s]=0.6458605782 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.32 Tref[s]=0.6519772087 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.33 Tref[s]=0.6592059539 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.34 Tref[s]=0.6658786417 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.35 Tref[s]=0.6722733009 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.36 Tref[s]=0.6792240174 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.37 Tref[s]=0.6864527626 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.38 Tref[s]=0.6936815077 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.39 Tref[s]=0.7006322243 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.4 Tref[s]=0.7070268834 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.41 Tref[s]=0.7145336573 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.42 Tref[s]=0.7220404311 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.43 Tref[s]=0.7289911476 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.44 Tref[s]=0.7373320074 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.45 Tref[s]=0.7440046953 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.46 Tref[s]=0.7501213258 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.47 Tref[s]=0.756515985 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.48 Tref[s]=0.7643007875 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.49 Tref[s]=0.771251504 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.5 Tref[s]=0.7790363065 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.51 Tref[s]=0.786821109 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.52 Tref[s]=0.7926597109 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.53 Tref[s]=0.7993323987 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.54 Tref[s]=0.8073952299 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.55 Tref[s]=0.814623975 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.56 Tref[s]=0.8221307489 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.57 Tref[s]=0.8290814654 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.58 Tref[s]=0
Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.17 Tref[s]=0.9920062604 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=2.18 Tref[s]=0.9992350055 Ecool[%]=0 Core[%]=0 Impact=0
# STOP -2024/12/19-14:16:42
#
# TODO: simple version here...
# 3it [06:52, 137.53s/it]
# BETACOOL----------release ver.7.2.beta (omp)----------2024/12/19
# ../../betacool/Betacool ../../LEIR.bld /m
# Input parameter [12,11] was initialised with default value:1e+10
# Cannot open file : Bring3.bump
# Mean beam radius= 0.1370049566  is more than chamber 4
# Model Beam: Integration Step [sec] =0.0002780286604
# Tcal[m.s]=0 Tref[s]=0 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.01 Tref[s]=0.007506773831 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.02 Tref[s]=0.01529157632 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.03 Tref[s]=0.02140820685 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.04 Tref[s]=0.02752483738 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.05 Tref[s]=0.03475358255 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.06 Tref[s]=0.04226035638 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.07 Tref[s]=0.04865501557 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.08 Tref[s]=0.05643981806 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.09 Tref[s]=0.06283447725 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.1 Tref[s]=0.06978519377 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.11 Tref[s]=0.07534576697 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.12 Tref[s]=0.08257451214 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.13 Tref[s]=0.0906373433 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.14 Tref[s]=0.09897820311 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.15 Tref[s]=0.1073190629 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.16 Tref[s]=0.1142697794 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.17 Tref[s]=0.119552324 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.18 Tref[s]=0.1273371265 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.19 Tref[s]=0.134287843 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.2 Tref[s]=0.1420726455 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.21 Tref[s]=0.1493013906 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.22 Tref[s]=0.1570861931 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.23 Tref[s]=0.1634808523 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.24 Tref[s]=0.1693194542 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.25 Tref[s]=0.1771042567 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.26 Tref[s]=0.1846110305 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.27 Tref[s]=0.1896155464 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.28 Tref[s]=0.1974003489 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.29 Tref[s]=0.2046290941 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.3 Tref[s]=0.2118578392 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.31 Tref[s]=0.2204767277 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.32 Tref[s]=0.2274274442 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.33 Tref[s]=0.235768304 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.34 Tref[s]=0.2435531065 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.35 Tref[s]=0.250503823 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.36 Tref[s]=0.2585666542 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.37 Tref[s]=0.2680196286 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.38 Tref[s]=0.2763604885 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.39 Tref[s]=0.2852574056 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.4 Tref[s]=0.2930422081 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.41 Tref[s]=0.3005489819 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.42 Tref[s]=0.3088898417 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.43 Tref[s]=0.3177867589 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.44 Tref[s]=0.32584959 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.45 Tref[s]=0.3336343925 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.46 Tref[s]=0.3411411663 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.47 Tref[s]=0.3475358255 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.48 Tref[s]=0.3547645707 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.49 Tref[s]=0.3608812012 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.5 Tref[s]=0.3686660037 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.51 Tref[s]=0.3761727775 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.52 Tref[s]=0.3814553221 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.53 Tref[s]=0.3889620959 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.54 Tref[s]=0.3961908411 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.55 Tref[s]=0.4045317009 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.56 Tref[s]=0.4125945321 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.57 Tref[s]=0.4206573632 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.58 Tref[s]=0.4278861084 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.59 Tref[s]=0.4359489395 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1 Tref[s]=0.4423435987 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.01 Tref[s]=0.4498503726 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.02 Tref[s]=0.4587472897 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.03 Tref[s]=0.4659760349 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.04 Tref[s]=0.4723706941 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.05 Tref[s]=0.4787653532 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.06 Tref[s]=0.4859940984 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.07 Tref[s]=0.4940569296 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.08 Tref[s]=0.5012856747 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.09 Tref[s]=0.5087924486 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.1 Tref[s]=0.5154651364 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.11 Tref[s]=0.5218597956 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.12 Tref[s]=0.5288105121 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.13 Tref[s]=0.5363172859 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.14 Tref[s]=0.5449361744 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.15 Tref[s]=0.5535550629 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.16 Tref[s]=0.5607838081 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.17 Tref[s]=0.5682905819 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.18 Tref[s]=0.576353413 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.19 Tref[s]=0.5841382155 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.2 Tref[s]=0.5916449894 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.21 Tref[s]=0.5997078205 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.22 Tref[s]=0.6077706517 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.23 Tref[s]=0.6144433395 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.24 Tref[s]=0.6216720847 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.25 Tref[s]=0.6297349158 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.26 Tref[s]=0.6416901482 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.27 Tref[s]=0.6536453806 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.28 Tref[s]=0.6608741258 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.29 Tref[s]=0.6683808996 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.3 Tref[s]=0.6778338741 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.31 Tref[s]=0.6867307912 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.32 Tref[s]=0.6947936224 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.33 Tref[s]=0.7031344822 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.34 Tref[s]=0.7109192847 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.35 Tref[s]=0.7187040872 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.36 Tref[s]=0.7276010043 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.37 Tref[s]=0.7356638355 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.38 Tref[s]=0.7440046953 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.39 Tref[s]=0.7517894978 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.4 Tref[s]=0.7598523289 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.41 Tref[s]=0.7687492461 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.42 Tref[s]=0.7770901059 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.43 Tref[s]=0.7854309657 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.44 Tref[s]=0.7937718255 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.45 Tref[s]=0.8012785993 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.46 Tref[s]=0.8093414305 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.47 Tref[s]=0.817960319 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.48 Tref[s]=0.8260231501 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.49 Tref[s]=0.8332518953 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=1.5 Tref[s]=0.8415927551 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# ...
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=2 Tref[s]=0.9236112099 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=2.01 Tref[s]=0.9322300984 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=2.02 Tref[s]=0.9408489869 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=2.03 Tref[s]=0.9486337893 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=2.04 Tref[s]=0.9572526778 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=2.05 Tref[s]=0.965315509 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=2.06 Tref[s]=0.9736563688 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=2.07 Tref[s]=0.9817191999 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=2.08 Tref[s]=0.9897820311 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# Tcal[m.s]=2.09 Tref[s]=0.9984009196 Ecool[%]=0 Core[%]=0 Impact=0
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# doubleU::operator/(doubleU): division by zero
# STOP -2024/12/19-14:18:52
#
# TODO: simple version here...
