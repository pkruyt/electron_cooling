# %%
import numpy as np
import matplotlib.pyplot as plt
from pybetacool import PyBetaCool
from tqdm import tqdm


current_list = [1,2,3] # A

for i,current in tqdm(enumerate(current_list)):
    BLDfilename = '/home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld'
    betacoolExec = '/home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool'
    obj = PyBetaCool(BLDfilename=BLDfilename, betacoolExec=betacoolExec)
    # Edit one parameter (row=50, 4th value is "magnetic field")
    obj.BLDContent[55][2] = current 
    # Overwrites LEIR.bld with new setting 
    obj.BLDContent.save(BLDfilename)
    # Execute Betacool
    obj.runBetacool('/m')
    tmp = obj.parseCurveFile('emittance.cur')

    time=tmp[:,0]
    emittance_x = tmp[:,1]*1e-6
    emittance_y = tmp[:,2]*1e-6
    dp_p=tmp[:,3]

    filpath=f'results/emittance_betacool_I={current}.npz'
     #reset the bld file back to default 
    obj.BLDContent[55][2] = 0.6
    # Overwrites LEIR.bld with new setting 
    obj.BLDContent.save(BLDfilename)
    
    np.savez(filpath, time=time, emittance_x=emittance_x, emittance_y=emittance_y, dp_p=dp_p)
# Out:
# 1it [01:53, 113.54s/it]
# BETACOOL----------release ver.7.2.beta (omp)----------2023/7/13
# /home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool /home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld /m
# Input parameter [12,11] was initialised with default value:1e+10
# Cannot open file : Bring3.bump
# Mean beam radius= 0.1370049566  is more than chamber 4
# Model Beam: Integration Step [sec] =0.0002780286604
# Tcal[m.s]=0 Tref[s]=0 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.01 Tref[s]=0.004448458567 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.02 Tref[s]=0.01251128972 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.03 Tref[s]=0.02029609221 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.04 Tref[s]=0.02863695202 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.05 Tref[s]=0.0372558405 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.06 Tref[s]=0.04448458567 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.07 Tref[s]=0.05254741682 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.08 Tref[s]=0.06061024797 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.09 Tref[s]=0.06895110778 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.1 Tref[s]=0.07617985295 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.11 Tref[s]=0.08368662679 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.12 Tref[s]=0.09147142928 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.13 Tref[s]=0.09842214579 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.14 Tref[s]=0.1078751202 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.15 Tref[s]=0.1167720374 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.16 Tref[s]=0.1265030405 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.17 Tref[s]=0.1362340436 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.18 Tref[s]=0.1448529321 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.19 Tref[s]=0.1529157632 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.2 Tref[s]=0.1623687377 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.21 Tref[s]=0.1729338268 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.22 Tref[s]=0.1834989159 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.23 Tref[s]=0.1926738617 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.24 Tref[s]=0.2010147215 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.25 Tref[s]=0.2101896673 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.26 Tref[s]=0.2182524984 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.27 Tref[s]=0.2285395589 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.28 Tref[s]=0.2343781607 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.29 Tref[s]=0.2402167626 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.3 Tref[s]=0.2471674791 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.31 Tref[s]=0.2549522816 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.32 Tref[s]=0.2616249695 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.33 Tref[s]=0.2677416 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.34 Tref[s]=0.2733021732 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.35 Tref[s]=0.279974861 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.36 Tref[s]=0.2866475489 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.37 Tref[s]=0.2930422081 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.38 Tref[s]=0.2994368673 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.39 Tref[s]=0.3058315265 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.4 Tref[s]=0.3122261856 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.41 Tref[s]=0.3191769022 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.42 Tref[s]=0.3264056473 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.43 Tref[s]=0.3333563638 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.44 Tref[s]=0.3400290517 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.45 Tref[s]=0.3464237109 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.46 Tref[s]=0.3539304847 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.47 Tref[s]=0.3606031726 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.48 Tref[s]=0.3672758604 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.49 Tref[s]=0.3742265769 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.5 Tref[s]=0.3808992648 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.51 Tref[s]=0.3878499813 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.52 Tref[s]=0.3953567551 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.53 Tref[s]=0.402029443 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.54 Tref[s]=0.4087021308 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.55 Tref[s]=0.415930876 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.56 Tref[s]=0.4223255352 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.57 Tref[s]=0.4292762517 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.58 Tref[s]=0.4365049969 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.59 Tref[s]=0.4426216274 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1 Tref[s]=0.4490162866 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.01 Tref[s]=0.4559670031 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.02 Tref[s]=0.4623616623 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.03 Tref[s]=0.4690343501 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.04 Tref[s]=0.4762630953 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.05 Tref[s]=0.4826577545 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.06 Tref[s]=0.4890524137 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.07 Tref[s]=0.4979493308 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.08 Tref[s]=0.5093485059 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.09 Tref[s]=0.5204696523 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.1 Tref[s]=0.5318688274 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.11 Tref[s]=0.5435460311 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.12 Tref[s]=0.5546671775 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.13 Tref[s]=0.565788324 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.14 Tref[s]=0.577187499 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.15 Tref[s]=0.5877525881 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.16 Tref[s]=0.5980396486 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.17 Tref[s]=0.6086047377 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.18 Tref[s]=0.6191698268 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.19 Tref[s]=0.6297349158 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.2 Tref[s]=0.6405780336 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.21 Tref[s]=0.6514211514 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.22 Tref[s]=0.6622642691 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.23 Tref[s]=0.6736634442 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.24 Tref[s]=0.6850626193 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.25 Tref[s]=0.695905737 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.26 Tref[s]=0.7067488548 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.27 Tref[s]=0.7178700012 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.28 Tref[s]=0.728713119 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.29 Tref[s]=0.7390001794 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.3 Tref[s]=0.7498432971 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.31 Tref[s]=0.7609644436 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.32 Tref[s]=0.7715295327 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.33 Tref[s]=0.7823726504 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.34 Tref[s]=0.7932157682 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.35 Tref[s]=0.8037808573 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.36 Tref[s]=0.8143459464 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.37 Tref[s]=0.8251890641 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.38 Tref[s]=0.8357541532 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.39 Tref[s]=0.8460412137 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.4 Tref[s]=0.8571623601 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.41 Tref[s]=0.8680054778 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.42 Tref[s]=0.8788485956 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.43 Tref[s]=0.8896917133 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.44 Tref[s]=0.9002568024 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.45 Tref[s]=0.9105438629 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.46 Tref[s]=0.9208309233 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.47 Tref[s]=0.9311179837 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.48 Tref[s]=0.9419611015 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.49 Tref[s]=0.9528042193 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.5 Tref[s]=0.9633693083 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.51 Tref[s]=0.9742124261 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.52 Tref[s]=0.9850555439 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.53 Tref[s]=0.995620633 Ecool[%]=0 Core[%]=0 Impact=0
# STOP -2023/7/13-10:32:53
#
# TODO: simple version here...
# 2it [03:23, 99.81s/it]
# BETACOOL----------release ver.7.2.beta (omp)----------2023/7/13
# /home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool /home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld /m
# Input parameter [12,11] was initialised with default value:1e+10
# Cannot open file : Bring3.bump
# Mean beam radius= 0.1370049566  is more than chamber 4
# Model Beam: Integration Step [sec] =0.0002780286604
# Tcal[m.s]=0 Tref[s]=0 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.01 Tref[s]=0.0105650891 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.02 Tref[s]=0.02196426417 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.03 Tref[s]=0.03280738193 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.04 Tref[s]=0.04448458567 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.05 Tref[s]=0.05588376074 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.06 Tref[s]=0.0667268785 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.07 Tref[s]=0.07784802492 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.08 Tref[s]=0.08924719999 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.09 Tref[s]=0.1003683464 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.1 Tref[s]=0.1114894928 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.11 Tref[s]=0.1228886679 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.12 Tref[s]=0.1340098143 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.13 Tref[s]=0.1448529321 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.14 Tref[s]=0.1559740785 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.15 Tref[s]=0.