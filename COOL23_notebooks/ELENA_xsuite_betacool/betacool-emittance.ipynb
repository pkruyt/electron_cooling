# %%
import numpy as np
import matplotlib.pyplot as plt
from pybetacool import PyBetaCool
from tqdm import tqdm


BLDfilename = '/home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld'
betacoolExec = '/home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool'
obj = PyBetaCool(BLDfilename=BLDfilename, betacoolExec=betacoolExec)
obj.runBetacool('/m')
tmp = obj.parseCurveFile('emittance.cur')

time=tmp[:,0]
emittance_x = tmp[:,1]*1e-6
emittance_y = tmp[:,2]*1e-6
dp_p=tmp[:,3]

filpath='results/emittance_betacool.npz'

np.savez(filpath, time=time, emittance_x=emittance_x, emittance_y=emittance_y, dp_p=dp_p)
# Out:
# BETACOOL----------release ver.7.2.beta (omp)----------2023/7/13
# /home/pkruyt/cernbox/BETACOOL_ecooling/betacool/Betacool /home/pkruyt/cernbox/BETACOOL_ecooling/benchmarking-Betacool/LEIR.bld /m
# Input parameter [12,11] was initialised with default value:1e+10
# Cannot open file : Bring3.bump
# Mean beam radius= 0.1370049566  is more than chamber 4
# Model Beam: Integration Step [sec] =0.0002780286604
# Tcal[m.s]=0 Tref[s]=0 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=0.01 Tref[s]=0.00695071651 Ecool[%]=0.02 Core[%]=0 Impact=0
# Tcal[m.s]=0.02 Tref[s]=0.01501354766 Ecool[%]=0.03 Core[%]=0 Impact=0
# Tcal[m.s]=0.03 Tref[s]=0.02224229283 Ecool[%]=0.11 Core[%]=0 Impact=0
# Tcal[m.s]=0.04 Tref[s]=0.03030512399 Ecool[%]=0.21 Core[%]=0 Impact=0
# Tcal[m.s]=0.05 Tref[s]=0.03753386916 Ecool[%]=0.16 Core[%]=0 Impact=0
# Tcal[m.s]=0.06 Tref[s]=0.04476261433 Ecool[%]=0.4 Core[%]=0 Impact=0
# Tcal[m.s]=0.07 Tref[s]=0.0519913595 Ecool[%]=0.44 Core[%]=0 Impact=0
# Tcal[m.s]=0.08 Tref[s]=0.06005419065 Ecool[%]=0.38 Core[%]=0 Impact=0
# Tcal[m.s]=0.09 Tref[s]=0.06728293582 Ecool[%]=0.36 Core[%]=0 Impact=0
# Tcal[m.s]=0.1 Tref[s]=0.07506773831 Ecool[%]=0.41 Core[%]=0 Impact=0
# Tcal[m.s]=0.11 Tref[s]=0.08201845482 Ecool[%]=0.5 Core[%]=0 Impact=0
# Tcal[m.s]=0.12 Tref[s]=0.09035931464 Ecool[%]=0.36 Core[%]=0 Impact=0
# Tcal[m.s]=0.13 Tref[s]=0.09842214579 Ecool[%]=0.43 Core[%]=0 Impact=0
# Tcal[m.s]=0.14 Tref[s]=0.1064849769 Ecool[%]=0.43 Core[%]=0 Impact=0
# Tcal[m.s]=0.15 Tref[s]=0.1139917508 Ecool[%]=0.54 Core[%]=0 Impact=0
# Tcal[m.s]=0.16 Tref[s]=0.1217765533 Ecool[%]=0.41 Core[%]=0 Impact=0
# Tcal[m.s]=0.17 Tref[s]=0.1295613558 Ecool[%]=0.61 Core[%]=0 Impact=0
# Tcal[m.s]=0.18 Tref[s]=0.1379022156 Ecool[%]=0.38 Core[%]=0 Impact=0
# Tcal[m.s]=0.19 Tref[s]=0.1454089894 Ecool[%]=0.53 Core[%]=0 Impact=0
# Tcal[m.s]=0.2 Tref[s]=0.1531937919 Ecool[%]=0.34 Core[%]=0 Impact=0
# Tcal[m.s]=0.21 Tref[s]=0.1604225371 Ecool[%]=0.51 Core[%]=0 Impact=0
# Tcal[m.s]=0.22 Tref[s]=0.1679293109 Ecool[%]=0.42 Core[%]=0 Impact=0
# Tcal[m.s]=0.23 Tref[s]=0.1762701707 Ecool[%]=0.54 Core[%]=0 Impact=0
# Tcal[m.s]=0.24 Tref[s]=0.1843330019 Ecool[%]=0.46 Core[%]=0 Impact=0
# Tcal[m.s]=0.25 Tref[s]=0.1918397757 Ecool[%]=0.47 Core[%]=0 Impact=0
# Tcal[m.s]=0.26 Tref[s]=0.1993465495 Ecool[%]=0.51 Core[%]=0 Impact=0
# Tcal[m.s]=0.27 Tref[s]=0.2076874093 Ecool[%]=0.45 Core[%]=0 Impact=0
# Tcal[m.s]=0.28 Tref[s]=0.2151941832 Ecool[%]=0.47 Core[%]=0 Impact=0
# Tcal[m.s]=0.29 Tref[s]=0.222700957 Ecool[%]=0.48 Core[%]=0 Impact=0
# Tcal[m.s]=0.3 Tref[s]=0.2304857595 Ecool[%]=0.31 Core[%]=0 Impact=0
# Tcal[m.s]=0.31 Tref[s]=0.2385485906 Ecool[%]=0.44 Core[%]=0 Impact=0
# Tcal[m.s]=0.32 Tref[s]=0.2468894505 Ecool[%]=0.44 Core[%]=0 Impact=0
# Tcal[m.s]=0.33 Tref[s]=0.2543962243 Ecool[%]=0.35 Core[%]=0 Impact=0
# Tcal[m.s]=0.34 Tref[s]=0.2624590554 Ecool[%]=0.54 Core[%]=0 Impact=0
# Tcal[m.s]=0.35 Tref[s]=0.2702438579 Ecool[%]=0.37 Core[%]=0 Impact=0
# Tcal[m.s]=0.36 Tref[s]=0.2774726031 Ecool[%]=0.5 Core[%]=0 Impact=0
# Tcal[m.s]=0.37 Tref[s]=0.2858134629 Ecool[%]=0.44 Core[%]=0 Impact=0
# Tcal[m.s]=0.38 Tref[s]=0.2935982654 Ecool[%]=0.64 Core[%]=0 Impact=0
# Tcal[m.s]=0.39 Tref[s]=0.3013830679 Ecool[%]=0.38 Core[%]=0 Impact=0
# Tcal[m.s]=0.4 Tref[s]=0.3091678704 Ecool[%]=0.6 Core[%]=0 Impact=0
# Tcal[m.s]=0.41 Tref[s]=0.3177867589 Ecool[%]=0.53 Core[%]=0 Impact=0
# Tcal[m.s]=0.42 Tref[s]=0.3255715613 Ecool[%]=0.37 Core[%]=0 Impact=0
# Tcal[m.s]=0.43 Tref[s]=0.3330783352 Ecool[%]=0.45 Core[%]=0 Impact=0
# Tcal[m.s]=0.44 Tref[s]=0.340585109 Ecool[%]=0.43 Core[%]=0 Impact=0
# Tcal[m.s]=0.45 Tref[s]=0.3486479402 Ecool[%]=0.4 Core[%]=0 Impact=0
# Tcal[m.s]=0.46 Tref[s]=0.3575448573 Ecool[%]=0.44 Core[%]=0 Impact=0
# Tcal[m.s]=0.47 Tref[s]=0.3647736025 Ecool[%]=0.41 Core[%]=0 Impact=0
# Tcal[m.s]=0.48 Tref[s]=0.3720023476 Ecool[%]=0.51 Core[%]=0 Impact=0
# Tcal[m.s]=0.49 Tref[s]=0.3797871501 Ecool[%]=0.57 Core[%]=0 Impact=0
# Tcal[m.s]=0.5 Tref[s]=0.3881280099 Ecool[%]=0.51 Core[%]=0 Impact=0
# Tcal[m.s]=0.51 Tref[s]=0.3953567551 Ecool[%]=0.41 Core[%]=0 Impact=0
# Tcal[m.s]=0.52 Tref[s]=0.4028635289 Ecool[%]=0.38 Core[%]=0 Impact=0
# Tcal[m.s]=0.53 Tref[s]=0.4106483314 Ecool[%]=0.49 Core[%]=0 Impact=0
# Tcal[m.s]=0.54 Tref[s]=0.4184331339 Ecool[%]=0.53 Core[%]=0 Impact=0
# Tcal[m.s]=0.55 Tref[s]=0.4267739937 Ecool[%]=0.49 Core[%]=0 Impact=0
# Tcal[m.s]=0.56 Tref[s]=0.4345587962 Ecool[%]=0.42 Core[%]=0 Impact=0
# Tcal[m.s]=0.57 Tref[s]=0.4423435987 Ecool[%]=0.32 Core[%]=0 Impact=0
# Tcal[m.s]=0.58 Tref[s]=0.4498503726 Ecool[%]=0.3 Core[%]=0 Impact=0
# Tcal[m.s]=0.59 Tref[s]=0.4581912324 Ecool[%]=0.46 Core[%]=0 Impact=0
# Tcal[m.s]=1 Tref[s]=0.4656980062 Ecool[%]=0.38 Core[%]=0 Impact=0
# Tcal[m.s]=1.01 Tref[s]=0.47320478 Ecool[%]=0.39 Core[%]=0 Impact=0
# Tcal[m.s]=1.02 Tref[s]=0.4807115539 Ecool[%]=0.5 Core[%]=0 Impact=0
# Tcal[m.s]=1.03 Tref[s]=0.488774385 Ecool[%]=0.5 Core[%]=0 Impact=0
# Tcal[m.s]=1.04 Tref[s]=0.4976713021 Ecool[%]=0.42 Core[%]=0 Impact=0
# Tcal[m.s]=1.05 Tref[s]=0.505178076 Ecool[%]=0.46 Core[%]=0 Impact=0
# Tcal[m.s]=1.06 Tref[s]=0.5129628785 Ecool[%]=0.51 Core[%]=0 Impact=0
# Tcal[m.s]=1.07 Tref[s]=0.5210257096 Ecool[%]=0.44 Core[%]=0 Impact=0
# Tcal[m.s]=1.08 Tref[s]=0.5290885408 Ecool[%]=0.47 Core[%]=0 Impact=0
# Tcal[m.s]=1.09 Tref[s]=0.5374294006 Ecool[%]=0.36 Core[%]=0 Impact=0
# Tcal[m.s]=1.1 Tref[s]=0.5449361744 Ecool[%]=0.43 Core[%]=0 Impact=0
# Tcal[m.s]=1.11 Tref[s]=0.5527209769 Ecool[%]=0.37 Core[%]=0 Impact=0
# Tcal[m.s]=1.12 Tref[s]=0.5605057794 Ecool[%]=0.36 Core[%]=0 Impact=0
# Tcal[m.s]=1.13 Tref[s]=0.5677345246 Ecool[%]=0.41 Core[%]=0 Impact=0
# Tcal[m.s]=1.14 Tref[s]=0.576353413 Ecool[%]=0.6 Core[%]=0 Impact=0
# Tcal[m.s]=1.15 Tref[s]=0.5841382155 Ecool[%]=0.54 Core[%]=0 Impact=0
# Tcal[m.s]=1.16 Tref[s]=0.5913669607 Ecool[%]=0.31 Core[%]=0 Impact=0
# Tcal[m.s]=1.17 Tref[s]=0.5991517632 Ecool[%]=0.4 Core[%]=0 Impact=0
# Tcal[m.s]=1.18 Tref[s]=0.607492623 Ecool[%]=0.42 Core[%]=0 Impact=0
# Tcal[m.s]=1.19 Tref[s]=0.6149993968 Ecool[%]=0.42 Core[%]=0 Impact=0
# Tcal[m.s]=1.2 Tref[s]=0.622228142 Ecool[%]=0.45 Core[%]=0 Impact=0
# Tcal[m.s]=1.21 Tref[s]=0.6297349158 Ecool[%]=0.45 Core[%]=0 Impact=0
# Tcal[m.s]=1.22 Tref[s]=0.6380757757 Ecool[%]=0.35 Core[%]=0 Impact=0
# Tcal[m.s]=1.23 Tref[s]=0.6455825495 Ecool[%]=0.45 Core[%]=0 Impact=0
# Tcal[m.s]=1.24 Tref[s]=0.6530893233 Ecool[%]=0.39 Core[%]=0 Impact=0
# Tcal[m.s]=1.25 Tref[s]=0.6608741258 Ecool[%]=0.42 Core[%]=0 Impact=0
# Tcal[m.s]=1.26 Tref[s]=0.6692149856 Ecool[%]=0.29 Core[%]=0 Impact=0
# Tcal[m.s]=1.27 Tref[s]=0.6775558454 Ecool[%]=0.51 Core[%]=0 Impact=0
# Tcal[m.s]=1.28 Tref[s]=0.6850626193 Ecool[%]=0.47 Core[%]=0 Impact=0
# Tcal[m.s]=1.29 Tref[s]=0.6928474218 Ecool[%]=0.4 Core[%]=0 Impact=0
# Tcal[m.s]=1.3 Tref[s]=0.7009102529 Ecool[%]=0.35 Core[%]=0 Impact=0
# Tcal[m.s]=1.31 Tref[s]=0.7084170267 Ecool[%]=0.4 Core[%]=0 Impact=0
# Tcal[m.s]=1.32 Tref[s]=0.7164798579 Ecool[%]=0.32 Core[%]=0 Impact=0
# Tcal[m.s]=1.33 Tref[s]=0.7242646604 Ecool[%]=0.21 Core[%]=0 Impact=0
# Tcal[m.s]=1.34 Tref[s]=0.7314934056 Ecool[%]=0.32 Core[%]=0 Impact=0
# Tcal[m.s]=1.35 Tref[s]=0.7387221507 Ecool[%]=0.21 Core[%]=0 Impact=0
# Tcal[m.s]=1.36 Tref[s]=0.7470630105 Ecool[%]=0.28 Core[%]=0 Impact=0
# Tcal[m.s]=1.37 Tref[s]=0.7545697844 Ecool[%]=0.2 Core[%]=0 Impact=0
# Tcal[m.s]=1.38 Tref[s]=0.7620765582 Ecool[%]=0.18 Core[%]=0 Impact=0
# Tcal[m.s]=1.39 Tref[s]=0.7698613607 Ecool[%]=0.14 Core[%]=0 Impact=0
# Tcal[m.s]=1.4 Tref[s]=0.7779241919 Ecool[%]=0.17 Core[%]=0 Impact=0
# Tcal[m.s]=1.41 Tref[s]=0.7857089943 Ecool[%]=0.11 Core[%]=0 Impact=0
# Tcal[m.s]=1.42 Tref[s]=0.7932157682 Ecool[%]=0.15 Core[%]=0 Impact=0
# Tcal[m.s]=1.43 Tref[s]=0.800722542 Ecool[%]=0.1 Core[%]=0 Impact=0
# Tcal[m.s]=1.44 Tref[s]=0.8079512872 Ecool[%]=0.07 Core[%]=0 Impact=0
# Tcal[m.s]=1.45 Tref[s]=0.8165701756 Ecool[%]=0.08 Core[%]=0 Impact=0
# Tcal[m.s]=1.46 Tref[s]=0.8237989208 Ecool[%]=0.07 Core[%]=0 Impact=0
# Tcal[m.s]=1.47 Tref[s]=0.831027666 Ecool[%]=0.08 Core[%]=0 Impact=0
# Tcal[m.s]=1.48 Tref[s]=0.8390904971 Ecool[%]=0.11 Core[%]=0 Impact=0
# Tcal[m.s]=1.49 Tref[s]=0.8477093856 Ecool[%]=0.05 Core[%]=0 Impact=0
# Tcal[m.s]=1.5 Tref[s]=0.8552161594 Ecool[%]=0.04 Core[%]=0 Impact=0
# Tcal[m.s]=1.51 Tref[s]=0.8627229333 Ecool[%]=0.04 Core[%]=0 Impact=0
# Tcal[m.s]=1.52 Tref[s]=0.8707857644 Ecool[%]=0.1 Core[%]=0 Impact=0
# Tcal[m.s]=1.53 Tref[s]=0.8780145096 Ecool[%]=0.04 Core[%]=0 Impact=0
# Tcal[m.s]=1.54 Tref[s]=0.8863553694 Ecool[%]=0.02 Core[%]=0 Impact=0
# Tcal[m.s]=1.55 Tref[s]=0.8935841146 Ecool[%]=0.03 Core[%]=0 Impact=0
# Tcal[m.s]=1.56 Tref[s]=0.9010908884 Ecool[%]=0 Core[%]=0 Impact=0
# Tcal[m.s]=1.57 Tref[s]=0.9085976622 Ecool[%]=0.05 Core[%]=0 Impact=0
# Tcal[m.s]=1.58 Tref[s]=0.9166604934 Ecool[%]=0.06 Core[%]=0 Impact=0
# Tcal[m.s]=1.59 Tref[s]=0.9238892386 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=2 Tref[s]=0.9316740411 Ecool[%]=0.04 Core[%]=0 Impact=0
# Tcal[m.s]=2.01 Tref[s]=0.9394588436 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=2.02 Tref[s]=0.9475216747 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=2.03 Tref[s]=0.9553064772 Ecool[%]=0.04 Core[%]=0 Impact=0
# Tcal[m.s]=2.04 Tref[s]=0.962813251 Ecool[%]=0.03 Core[%]=0 Impact=0
# Tcal[m.s]=2.05 Tref[s]=0.9703200249 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=2.06 Tref[s]=0.9778267987 Ecool[%]=0.01 Core[%]=0 Impact=0
# Tcal[m.s]=2.07 Tref[s]=0.9864456872 Ecool[%]=0.03 Core[%]=0 Impact=0
# Tcal[m.s]=2.08 Tref[s]=0.993952461 Ecool[%]=0.04 Core[%]=0 Impact=0
# STOP -2023/7/13-15:13:16
#
# TODO: simple version here...
