# %%
import numpy as np
import os
import numpy as np
# import matplotlib.pyplot as plt
# # Specify the file paths of the saved data
# second_moment_file = 'output/metrics/2nd-moment.npz'
# iqr_file = 'output/metrics/IQR.npz'
min_distance_file='output/metrics/min_distance_metric.npz'

# # Load the data from the "2nd moment" file
# second_moment_data = np.load(second_moment_file)

# # Extract the arrays from the loaded data
# min_distance_x_second_moment = second_moment_data['min_distance_x_list']
# point_x_second_moment = second_moment_data['point_x_list']
# min_distance_delta_second_moment = second_moment_data['min_distance_delta_list']
# point_delta_second_moment = second_moment_data['point_delta_list']

# # Load the data from the "IQR" file
# iqr_data = np.load(iqr_file)

# # Extract the arrays from the loaded data
# q1_x_iqr = iqr_data['q1_x_list']
# point_x_iqr = iqr_data['point_x_list']
# q3_x_iqr = iqr_data['q3_x_list']
# q1_delta_iqr = iqr_data['q1_delta_list']
# point_delta_iqr = iqr_data['point_delta_list']
# q3_delta_iqr = iqr_data['q3_delta_list']



min_distance_data = np.load(min_distance_file)

min_distance_x_array = min_distance_data['min_distance_x_list']
min_distance_point_x_array = min_distance_data['point_x_list']
min_distance_delta_array = min_distance_data['min_distance_delta_list']
min_distance_point_delta_array = min_distance_data['point_delta_list']


# # time = np.arange(0, 100) * s_per_turn   
# # Plot the arrays
# plt.figure()
# # plt.fill_between(range(len(point_x_second_moment)),
# #                  point_x_second_moment + min_distance_x_second_moment,
# #                  point_x_second_moment - min_distance_x_second_moment,
# #                  color='green',  
# #                  alpha=0.2,
# #                  label='second moment'
# #                  )
# # plt.plot(point_x_second_moment,color='green',linestyle='--',alpha=0.6)
# # plt.fill_between(range(len(point_x_second_moment)),
# #                  min_distance_point_x_array + min_distance_x_array,
# #                  min_distance_point_x_array - min_distance_x_array,
# #                  color='blue',  
# #                  alpha=0.2,
# #                  label='min distance'
# #                  )

# plt.plot(min_distance_point_x_array,color='blue',linestyle='--',alpha=0.6)

# # plt.fill_between(range(len(point_x_second_moment)),
# #                  q1_x_iqr,
# #                  q3_x_iqr,
# #                  color='red',  
# #                  alpha=0.1,
# #                  label='IQR'
# #                  )
# plt.plot(min_distance_point_x_array + min_distance_x_array,label='min distance')
# plt.plot(min_distance_point_x_array - min_distance_x_array,label='min distance')


# plt.legend(loc='best')
# plt.show()

# %%
import numpy as np
import os
import numpy as np
import matplotlib.pyplot as plt



second_moment_file = 'output/metrics/2nd-moment.npz'
second_moment_data = np.load(second_moment_file)

# Extract the arrays from the loaded data
min_distance_x_second_moment = second_moment_data['min_distance_x_list']
point_x_second_moment = second_moment_data['point_x_list']
min_distance_delta_second_moment = second_moment_data['min_distance_delta_list']
point_delta_second_moment = second_moment_data['point_delta_list']



iqr_file = 'output/metrics/IQR.npz'
iqr_data = np.load(iqr_file)

# Extract the arrays from the loaded data
q1_x_iqr = iqr_data['q1_x_list']
point_x_iqr = iqr_data['point_x_list']
q3_x_iqr = iqr_data['q3_x_list']
q1_delta_iqr = iqr_data['q1_delta_list']
point_delta_iqr = iqr_data['point_delta_list']
q3_delta_iqr = iqr_data['q3_delta_list']


min_distance_file='output/metrics/min_distance_metric.npz'


min_distance_data = np.load(min_distance_file)

min_distance_x_array = min_distance_data['min_distance_x_list']
min_distance_point_x_array = min_distance_data['point_x_list']
min_distance_delta_array = min_distance_data['min_distance_delta_list']
min_distance_point_delta_array = min_distance_data['point_delta_list']


plt.figure()
# plt.fill_between(range(len(point_x_second_moment)),
#                  point_x_second_moment + min_distance_x_second_moment,
#                  point_x_second_moment - min_distance_x_second_moment,
#                  color='green',  
#                  alpha=0.2,
#                  label='second moment'
#                  )
# plt.plot(point_x_second_moment,color='green',linestyle='--',alpha=0.6)
# plt.fill_between(range(len(point_x_second_moment)),
#                  min_distance_point_x_array + min_distance_x_array,
#                  min_distance_point_x_array - min_distance_x_array,
#                  color='blue',  
#                  alpha=0.2,
#                  label='min distance'
#                  )


plt.plot(point_x_second_moment,color='blue',linestyle='--',label='second moment')
plt.plot(point_x_second_moment + min_distance_x_second_moment,color='blue',label='_no_label_')
plt.plot(point_x_second_moment - min_distance_x_second_moment,color='blue',label='_no_label_')



# plt.plot(min_distance_point_x_array,color='red',linestyle='--',label='min distance')
# plt.plot(min_distance_point_x_array + min_distance_x_array,color='red',label='_no_label_')
# plt.plot(min_distance_point_x_array - min_distance_x_array,color='red',label='_no_label_')



plt.plot(q1_x_iqr,color='black',linestyle='-',label='histogram')
plt.plot(q3_x_iqr,color='black',linestyle='-',label='_no_label_')

# plt.fill_between(range(len(point_x_second_moment)),
#                  q1_x_iqr,
#                  q3_x_iqr,
#                  color='red',  
#                  alpha=0.1,
#                  label='IQR'
#                  )



plt.legend(loc='best')
plt.show()

# %%
plt.figure()
# plt.fill_between(range(len(point_x_second_moment)),
#                  point_x_second_moment + min_distance_x_second_moment,
#                  point_x_second_moment - min_distance_x_second_moment,
#                  color='green',  
#                  alpha=0.2,
#                  label='second moment'
#                  )
# plt.plot(point_x_second_moment,color='green',linestyle='--',alpha=0.6)
# plt.fill_between(range(len(point_x_second_moment)),
#                  min_distance_point_x_array + min_distance_x_array,
#                  min_distance_point_x_array - min_distance_x_array,
#                  color='blue',  
#                  alpha=0.2,
#                  label='min distance'
#                  )
step=100
num_turns=int(1e7)
s_per_turn=1.9951813726709976e-06
time = np.linspace(0, num_turns, 100)*s_per_turn


plt.plot(time,min_distance_x_second_moment*2,color='blue',linestyle='--',label='second moment')


plt.plot(time,min_distance_x_array*2,color='red',linestyle='--',label='min distance')


plt.plot(time,-q1_x_iqr+q3_x_iqr,color='black',linestyle='-',label='histogram')
# plt.fill_between(range(len(point_x_second_moment)),
#                  q1_x_iqr,
#                  q3_x_iqr,
#                  color='red',  
#                  alpha=0.1,
#                  label='IQR'
#                  )



plt.legend(loc='best')
plt.ylabel('metric x')
plt.xlabel('time [s]')


plt.show()

# %%
plt.figure()
# plt.fill_between(range(len(point_x_second_moment)),
#                  point_x_second_moment + min_distance_x_second_moment,
#                  point_x_second_moment - min_distance_x_second_moment,
#                  color='green',  
#                  alpha=0.2,
#                  label='second moment'
#                  )
# plt.plot(point_x_second_moment,color='green',linestyle='--',alpha=0.6)
# plt.fill_between(range(len(point_x_second_moment)),
#                  min_distance_point_x_array + min_distance_x_array,
#                  min_distance_point_x_array - min_distance_x_array,
#                  color='blue',  
#                  alpha=0.2,
#                  label='min distance'
#                  )
step=100
num_turns=int(1e7)
s_per_turn=1.9951813726709976e-06
time = np.linspace(0, num_turns, 100)*s_per_turn


plt.plot(time,min_distance_delta_second_moment*2*2,color='blue',linestyle='--',label='second moment')


plt.plot(time,min_distance_delta_array*2,color='red',linestyle='--',label='min distance')


plt.plot(time,-q1_delta_iqr+q3_delta_iqr,color='black',linestyle='-',label='histogram')
# plt.fill_between(range(len(point_x_second_moment)),
#                  q1_x_iqr,
#                  q3_x_iqr,
#                  color='red',  
#                  alpha=0.1,
#                  label='IQR'
#                  )



plt.legend(loc='best')
plt.ylabel('metric dp/p')
plt.xlabel('time [s]')


plt.show()
