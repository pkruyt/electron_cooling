# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# load data
data = np.load('cooling_time_data_4d_pos.npz')
cooling_time = data['cooling_time']
offset_x_values = data['offset_x_values']
offset_dp_values = data['offset_dp_values']
disp_values = data['disp_values']

# set up figure and axes
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# create meshgrid for 3D plot
X, Y, Z = np.meshgrid(offset_x_values, offset_dp_values, disp_values, indexing='ij')

# plot 3D heatmap
ax.scatter(X.flatten(), Y.flatten(), Z.flatten(), c=cooling_time.flatten(), cmap='viridis', alpha=0.8)

# set labels and title
ax.set_xlabel('Offset x [m]')
ax.set_ylabel('Offset dp/p')
ax.set_zlabel('Dispersion [m]')
ax.set_title('Cooling time')
#ax.view_init(elev=20, azim=-120)  # Adjust the elevation (elev) and azimuth (azim) angles as needed

# add colorbar
mappable = plt.cm.ScalarMappable(cmap='viridis')
mappable.set_array(cooling_time.flatten())
cbar = fig.colorbar(mappable, shrink=0.6)
cbar.set_label('Cooling time [s]')

plt.show()
# Out:
# /tmp/pkruyt/ipykernel_178533/1496288091.py:32: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = fig.colorbar(mappable, shrink=0.6)

# %%
cooling_time.shape
offset_dp_values
# Out:
# array([-1.00000000e-09, -9.48717949e-10, -8.97435897e-10, -8.46153846e-10,
#        -7.94871795e-10, -7.43589744e-10, -6.92307692e-10, -6.41025641e-10,
#        -5.89743590e-10, -5.38461538e-10, -4.87179487e-10, -4.35897436e-10,
#        -3.84615385e-10, -3.33333333e-10, -2.82051282e-10, -2.30769231e-10,
#        -1.79487179e-10, -1.28205128e-10, -7.69230769e-11, -2.56410256e-11,
#         2.56410256e-11,  7.69230769e-11,  1.28205128e-10,  1.79487179e-10,
#         2.30769231e-10,  2.82051282e-10,  3.33333333e-10,  3.84615385e-10,
#         4.35897436e-10,  4.87179487e-10,  5.38461538e-10,  5.89743590e-10,
#         6.41025641e-10,  6.92307692e-10,  7.43589744e-10,  7.94871795e-10,
#         8.46153846e-10,  8.97435897e-10,  9.48717949e-10,  1.00000000e-09])
